# %%
import re, json, tqdm, importlib, tltk, csv
import pandas as pd
import numpy as np
from collections import Counter
from pythainlp.corpus import thai_stopwords
from pythainlp import word_tokenize
import thaig2p

# %%
importlib.reload(thaig2p)
# Out:
# <module 'thaig2p' from '/Users/Nozomi/github/thaig2p/thaig2p.py'>

# %% [markdown]
# # get unknown frequent words

# %%
words = Counter()
nhk = pd.read_csv('nhk.csv')
for token_lst in tqdm.tqdm(nhk.tokens):
    g_p_list = thaig2p.g2p(eval(token_lst), return_tokens=1)
    for g, p in g_p_list:
        if p == None and len(g) > 6:
            words[g] += 1
# Out:
# 100%|██████████| 4640/4640 [00:13<00:00, 344.90it/s]

# %%
# write nophone words
with open('nophone.csv', 'w') as f:
    for i,j in words.most_common(200):
        f.write(i+',\n')

# %%
thaig2p.__get_phone_number('-1,242,345,345.12345')
# Out:
# 'lop4 nvN2 Pan1 sXN5 rXj4 sI-2 sip2 sXN5 lAn4 sAm5 sYN5 sI-2 mVn2 hA-3 Pan1 sAm5 rXj4 sI-2 sip2 hA-3 cut2 nvN2 sXN5 sAm5 sI-2 hA-3'

# %% [markdown]
# # guess unknown by tltk

# %%
with open('nophone.csv') as f:
    nophone = dict(csv.reader(f))

# %%
for k in nophone:
    p = thaig2p.__get_phone_word_tltk(k)
    print(k,p,sep=',')
# Out:
# เงินชดเชย,Nzn1 Cot4 CZj1
# อันเนื่องมาจาก,?an1 nWN3 mA-1 cAk2
# แต่กลับ,tY-2 klap2
# ดาวโจนส์,dAw1 cOn1
# อ้างคำพูด,?AN3 Kam1 PUt3
# ประเด็นหลัก,pra-2 den1 lak2
# แนวปะการัง,nYw1 pa-2 kA-1 raN1
# ยื่นข้อเสนอ,jVn3 KX-3 sa-2 nZ-5
# ผลการวิเคราะห์,Pon5 kAn1 wi-4 Krx-4
# ภายในบ้าน,PAj1 naj1 bAn3
# ชุมนุมกัน,Cum1 num1 kan1
# วิ่งมาราธอน,wiN3 mA-1 rA-1 TXn1
# คนวัยหนุ่มสาว,Kon1 waj1 num2 sAw5
# คลังสมอง,KlaN1 sa-2 mXN5
# ตามคำสั่ง,tAm1 Kam1 saN2
# เฉพาะเจาะจง,Ca-2 Px-4 cx-2 coN1
# บลูมเบิร์ก,ba-2 lUm1 bZk2
# ผลการศึกษา,Pon5 kAn1 svk2 sA-5
# พานาโซนิค,PA-1 nA-1 sO-1 nik2
# เวลาทำการ,wE-1 lA-1 Tam1 kAn1
# อิสตันบูล,?it2 tan1 bUn1
# ดาวอังคาร,dAw1 ?aN1 KAn1
# ทำกิจกรรม,Tam1 kit2 ca-2 kam1
# รับหน้าที่,rap4 nA-3 TI-3
# ส่งผลให้เกิด,soN2 Pon5 haj3 kZt2
# พระพันปี,Pra-4 Pan1 pI-1
# ชาติมหาอำนาจ,CAt3 ma-4 hA-5 ?am1 nAt3
# กรุงคาบูล,kruN1 KA-1 bUn1
# ถอนกำลัง,TXn5 kam1 laN1
# ขั้นต้น,Kan3 ton3
# ถ่ายโอน,TAj2 ?On1
# กัปตันเรือ,kap2 tan1 rW-1
# บาดเจ็บสาหัส,bAt2 cep2 sA-5 hat2
# ท้ายที่สุด,TAj4 TI-3 sut2
# รับข้อเสนอ,rap4 KX-3 sa-2 nZ-5
# เข้าด้วยกัน,Kaw3 dRj3 kan1
# เป็นได้,pen1 dAj3
# โฮลดิงส์,hOn1 diN1
# บันทึกภาพ,ban1 Tvk4 PAp3
# แหล่งท่องเที่ยว,lyN2 TXN3 TJw3
# มวลอากาศ,mRn1 ?A-1 kAt2
# เทศบัญญัติ,TEt3 sa-2 ban1 jat2
# กล่าวตอบ,klAw2 tXp2
# เหตุนี้,hEt2 nI-4
# พระตำหนัก,Pra-4 tam1 nak2
# พักอาศัย,Pak4 ?A-1 saj5
# กระทำการ,kra-2 Tam1 kAn1
# ของตลาด,KXN5 ta-2 lAt2
# เหรียญรางวัล,rJn5 rAN1 wan1
# ตามเงื่อนไข,tAm1 NWn3 Kaj5
# สิทธิเรียกร้อง,sit2 Ti-4 rJk3 rXN4
# หน่วยงานรัฐ,nRj2 NAn1 rat4
# มัธยมศึกษาตอนต้น,mat4 Ta-4 jom1 svk2 sA-5 tXn1 ton3
# เกี่ยวกับว่า,kJw2 kap2 wA-3
# ตกอยู่ในอันตราย,tok2 jU-2 naj1 ?an1 ta-2 rAj1
# เมืองแก,mWN1 kY-1
# พลิกฟื้น,Plik4 fVn4
# คว้ารางวัล,KwA-4 rAN1 wan1
# ทดลองใช้,Tot4 lXN1 Caj4
# บานสะพรั่ง,bAn1 sa-2 PraN3
# ร้อนที่,rXn4 TI-3
# ทิ้งตัว,TiN4 tR-1
# วัยหนุ่มสาว,waj1 num2 sAw5
# กดขี่ข่มเหง,kot2 KI-2 Kom2 hEN5
# สาธารณรัฐประชาธิปไตยคองโก,sA-5 TA-1 ra-4 na-4 rat4 Ta-2 pra-2 CA-1 Tip4 pa-2 taj1 KXN1 kO-1
# ตัดสิทธิ์,tat2 sit2
# ซานตาคลอส,sAn1 tA-1 KlXt3
# แล้วด้วย,lYw4 dRj3
# คนใกล้ชิด,Kon1 klaj3 Cit4
# ทำคะแนน,Tam1 Ka-4 nYn1
# จุดสนใจ,cut2 son5 caj1
# สำนักงานสถิติแห่งชาติ,sam5 nak4 NAn1 sa-2 Ti-2 ti-2 hyN2 CAt3
# มินดาเนา,min1 dA-1 naw1
# แลกเปลี่ยนความคิดเห็น,lYk3 plJn2 KwAm1 Kit4 hen5
# บัญชีดำ,ban1 CI-1 dam1
# เสียงส่วนใหญ่,sJN5 sRn2 jaj2
# รายงานประจำปี,rAj1 NAn1 pra-2 cam1 pI-1
# อูเอโนะ,?U-1 ?E-1 no-4
# มินนิโซตา,min1 ni-4 sO-1 tA-1
# รับบริจาค,rap4 bX-1 ri-4 cAk2
# เป็นผู้แทน,pen1 PU-3 TYn1
# อาจสามารถ,?At2 sA-5 mAt3
# ขนถ่ายสินค้า,Kon5 TAj2 sin5 KA-4
# ประสบอุบัติเหตุ,pra-2 sop2 ?u-2 bat2 ti-2 hEt2
# โดยทั่วไปแล้ว,dOj1 TR-3 paj1 lYw4
# คนผิวขาว,Kon1 Piw5 KAw5
# คอร์รัปชัน,KX-1 rap4 Can1
# เปิดร้าน,pZt2 rAn4
# โอเชียเนีย,?O-1 CJ-1 nJ-1
# ฉบับร่าง,Ca-2 bap2 rAN3
# ดิสนีย์แลนด์,dit2 nI-1 lYn1
# ใบอนุญาตขับรถ,baj1 ?a-2 nu-4 jAt3 Kap2 rot4
# ย่านการค้า,jAn3 kAn1 KA-4
# เงินทุนสำรอง,Nzn1 Tun1 sam5 rXN1
# สถานที่ทำงาน,sa-2 TAn5 TI-3 Tam1 NAn1
# ชั้นเรียน,Can4 rJn1
# เคมิคอล,KE-1 mi-4 KXn1
# งานประจำ,NAn1 pra-2 cam1
# เนชันแนล,nE-1 Can1 nYn1
# คลื่นวิทยุ,KlVn3 wit4 Ta-4 ju-4
# ประกาศตัว,pra-2 kAt2 tR-1
# ประพฤติผิด,pra-2 Prvt4 Pit2
# กองทุนสำรองเลี้ยงชีพ,kXN1 Tun1 sam5 rXN1 lJN4 CIp3
# งานเทศกาล,NAn1 TEt3 sa-2 kAn1
# สาธารณรัฐเช็ก,sA-5 TA-1 ra-4 na-4 rat4 Cek4
# ซ่วนโย่ว,sRn3 jOw3
# ลอสแอนเจลิส,lXt3 ?Yn1 cE-1 lit4
# หมดวาระ,mot2 wA-1 ra-4
# ทูลกระหม่อม,TUn1 kra-2 mXm2
# สถานกักกัน,sa-2 TAn5 kak2 kan1
# ถอนคำพูด,TXn5 Kam1 PUt3
# พื้นที่ต่ำ,PVn4 TI-3 tam2
# มาโกโตะ,mA-1 kO-1 to-2
# กล่าวย้ำ,klAw2 jam4
# ปิดกิจการ,pit2 kit2 ca-2 kAn1
# เลี้ยงเด็ก,lJN4 dek2
# ตามหลัง,tAm1 laN5
# คณะบริหาร,Ka-4 na-4 bX-1 ri-4 hAn5
# ปัจจัยหลัก,pat2 caj1 lak2
# เสียค่าใช้จ่าย,sJ-5 KA-3 Caj4 cAj2
# เปลี่ยนเป็น,plJn2 pen1
# บริษัทแม่,bX-1 ri-4 sat2 mY-3
# ในนามของ,naj1 nAm1 KXN5
# สนามสอบ,sa-2 nAm5 sXp2
# สวัสดิการสังคม,sa-2 wat2 di-2 kAn1 saN5 Kom1
# เสียที่,sJ-5 TI-3
# เจี๋ยฉือ,cJ-5 CV-5
# เซียงเซียง,sJN1 sJN1
# คนรุ่นใหม่,Kon1 run3 maj2
# กิจการค้า,kit2 kAn1 KA-4
# กั๋วอวี๋,kaw5 ?a-2 wI-5
# ย็อนฮัป,jxn1 hap4
# เว้นเสียแต่ว่า,wEn4 sJ-5 tY-2 wA-3
# อุปกรณ์การแพทย์,?u-2 pa-2 kXn1 kAn1 PYt3
# แอนติเจน,?Yn1 ti-2 cEn1
# ขบวนรถไฟ,Ka-2 bRn1 rot4 faj1
# แมนฮัตตัน,mYn1 hat4 tan1
# โรคไข้หวัดใหญ่,rOk3 Kaj3 wat2 jaj2
# เลขจำนวน,lEk3 cam1 nRn1
# ชิงชนะเลิศ,CiN1 Ca-4 na-4 lZt3
# โรมันคาทอลิก,rO-1 man1 KA-1 TX-1 lik2
# สภาจังหวัด,sa-2 PA-1 caN1 wat2
# บริษัทหลักทรัพย์,bX-1 ri-4 sat2 lak2 sap4
# ความคิดริเริ่ม,KwAm1 Kit4 ri-4 rZm3
# ถึงแก่ชีวิต,TvN5 kY-2 CI-1 wit4
# เมืองตากอากาศ,mWN1 tAk2 ?A-1 kAt2
# แมสซาชูเซตส์,mYt3 sA-1 CU-1 sEt3
# ชนพื้นเมือง,Con1 PVn4 mWN1
# ปรับโครงสร้าง,prap2 KrON1 sAN3
# ตราบเท่าที่,trAp2 Taw3 TI-3
# ตั้งเงื่อนไข,taN3 NWn3 Kaj5
# ได้ประโยชน์,dAj3 pra-2 jOt2
# ตามหลักการ,tAm1 lak2 kAn1
# คนรู้จัก,Kon1 rU-4 cak2
# เป็นอัตรา,pen1 ?at2 tra-1
# หมายกำหนดการ,mAj5 kam1 not2 kAn1
# หนาวเย็น,nAw5 jen1
# ราชินีนาถ,rA-1 Ci-4 nI-1 nAt3
# การค้นคว้าวิจัย,kAn1 Kon4 KwA-4 wi-4 caj1
# เพิ่มปริมาณ,PZm3 pa-2 ri-4 mAn1
# ตามคำแนะนำ,tAm1 Kam1 ny-4 nam1
# หน่วยกู้ภัย,nRj2 kU-3 Paj1
# จัดสรรเงิน,cat2 san5 Nzn1
# กล่าวเตือน,klAw2 tWn1
# เสาหลัก,saw5 lak2
# สืบราชสมบัติ,sVp2 rAt3 Ca-4 som5 bat2
# ข้อกล่าวอ้าง,KX-3 klAw2 ?AN3
# ถึงชีวิต,TvN5 CI-1 wit4
# กล่าวอ้าง,klAw2 ?AN3
# เงินตราต่างประเทศ,Nzn1 trA-1 tAN2 pra-2 TEt3
# โดยส่วนมาก,dOj1 sRn2 mAk3
# ตัดสินโทษ,tat2 sin5 TOt3
# เขตอุตสาหกรรม,KEt2 ?ut2 sA-5 ha-2 kam1
# อาฟเตอร์ช็อก,?Ap2 tZ-3 Cxk4
# เฝ้าทูลละอองพระบาท,faw3 TUn1 la-4 ?XN1 Pra-4 bAt2
# เป็นที่รับรู้,pen1 TI-3 rap4 rU-4
# ตราไปรษณียากร,trA-1 praj1 sa-2 nI-1 jA-1 kXn1
# ประจำจังหวัด,pra-2 cam1 caN1 wat2
# ผู้บริหารระดับสูง,PU-3 bX-1 ri-4 hAn5 ra-4 dap2 sUN5
# เป็นต้นแบบ,pen1 ton3 bYp2
# เรือขนส่งสินค้า,rW-1 Kon5 soN2 sin5 KA-4
# ละครโทรทัศน์,la-4 KXn1 TO-1 ra-4 Tat4
# ที่หวัง,TI-3 waN5

# %% [markdown]
# # test G2P

# %%
text = """เมื่อวันที่ 28 พ.ย. ที่ กองบังคับการปราบปราม (บก.ป.) พล.ต.ต.สุวัฒน์ แสงนุ่ม ผบก.ป. พ.ต.อ.ปทักข์ ขวัญนา ผกก.4 บก.ป. พ.ต.ท.ภัทรพันธ์ พูลทวี สว.กก.4 บก.ป. นำกำลังเจ้าหน้าที่ชุดปฏิบัติการ กก.4 บก.ป. สนธิกำลังร่วมกับเจ้าหน้าที่ บก.สส.ภ.6 จับกุม นายคง หรือพง บุญชาวนา อายุ 49 ปี ตามหมายจับศาลจังหวัดพิจิตรที่ 12/2553 ลงวันที่ 15 ม.ค. 2553 ข้อหา "ร่วมกันฆ่าผู้อื่นโดยเจตนา" ได้ที่ริมถนนสาธารณะ ซอย 9 ถนนบางแสนสาย 2 ต.แสนสุข อ.เมือง จ.ชลบุรี... อ่านต่อที่ : https://www.dailynews.co.th/crime/809598"""

# %%
thaig2p.g2p(text, return_tokens=0):
# Out:
# 'mɯ̂a wan tʰîi yîi sìp pɛ̀ɛt pʰrɯ́t sa cìʔ kaa yon tʰîi kɔɔŋ baŋ kʰáp kaan pràap praam ( bòk . pɔɔ ) pʰon tam rùat trii sùʔ wát  sɛ̌ɛŋ nûm pʰòp kɔɔ pɔɔ pʰan tam rùat ʔèek pɔɔ tʰák kʰwǎn naa pʰɔ̌ɔ kɔɔ kɔɔ sìi bòk . pɔɔ pʰan tam rùat tʰoo pʰát pʰan pʰuun tʰá wii sà wá . kìʔ loo kram sìi bòk . pɔɔ nam kam laŋ câw nâa tʰîi cʰút pa tìʔ bàt kaan kìʔ loo kram sìi bòk . pɔɔ sǒn tʰíʔ kam laŋ rûam ka câw nâa tʰîi bòk . sa mút sǒŋ kʰraam pʰɔɔ hòk càp kum naay kʰoŋ rɯ̌ɯ pʰoŋ bun cʰaaw naa ʔaa yúʔ sìi sìp kâaw pii taam mǎay càp sǎan caŋ wàt pʰíʔ cìt tʰîi sìp sɔ̌ɔŋ / sɔ̌ɔŋ pʰan hâa rɔ́ɔy hâa sìp sǎam loŋ wan tʰîi sìp hâa mók kà raa kʰom sɔ̌ɔŋ pʰan hâa rɔ́ɔy hâa sìp sǎam kʰɔ̂ɔ hǎa " rûam kan kʰâa pʰûu ʔɯ̀ɯn dooy cèet tà naa " dây tʰîi rim tʰà nǒn sǎa tʰaa rá ná sɔɔy kâaw tʰà nǒn baaŋ sɛ̌ɛn sǎay sɔ̌ɔŋ tam bon sɛ̌ɛn sùk ʔɔɔ mɯaŋ cɔɔ cʰon bùʔ rii ... ʔàan tɔ̀ɔ tʰîi :'

# %%
tokens = thaig2p.g2p(text, return_tokens=1)
for g, p in tokens:
    print(g,p,sep='\t')
# Out:
# เมื่อ	mɯ̂a
# วันที่	wan tʰîi
# 28	yîi sìp pɛ̀ɛt
# พ.ย.	pʰrɯ́t sa cìʔ kaa yon
# ที่	tʰîi
# กอง	kɔɔŋ
# บังคับการ	baŋ kʰáp kaan
# ปราบปราม	pràap praam
# (	(
# บก	bòk
# .	.
# ป.	pɔɔ
# )	)
# พล.ต.ต.	pʰon tam rùat trii
# สุ	sùʔ
# วัฒน	wát
# ์
# แสง	sɛ̌ɛŋ
# นุ่ม	nûm
# ผบ	pʰòp
# ก.	kɔɔ
# ป.	pɔɔ
# พ.ต.อ.	pʰan tam rùat ʔèek
# ป	pɔɔ
# ทักข์	tʰák
# ขวัญ	kʰwǎn
# นา	naa
# ผกก.	pʰɔ̌ɔ kɔɔ kɔɔ
# 4	sìi
# บก	bòk
# .	.
# ป.	pɔɔ
# พ.ต.ท.	pʰan tam rùat tʰoo
# ภัทร	pʰát
# พันธ์	pʰan
# พูล	pʰuun
# ทวี	tʰá wii
# สว	sà wá
# .	.
# กก.	kìʔ loo kram
# 4	sìi
# บก	bòk
# .	.
# ป.	pɔɔ
# นำ	nam
# กำลัง	kam laŋ
# เจ้าหน้าที่	câw nâa tʰîi
# ชุด	cʰút
# ปฏิบัติการ	pa tìʔ bàt kaan
# กก.	kìʔ loo kram
# 4	sìi
# บก	bòk
# .	.
# ป.	pɔɔ
# สนธิ	sǒn tʰíʔ
# กำลัง	kam laŋ
# ร่วมกับ	rûam ka
# เจ้าหน้าที่	câw nâa tʰîi
# บก	bòk
# .	.
# สส.	sɔ̌ɔ sɔ̌ɔ
# ภ.	pʰɔɔ
# 6	hòk
# จับกุม	càp kum
# นาย	naay
# คง	kʰoŋ
# หรือ	rɯ̌ɯ
# พง	pʰoŋ
# บุญ	bun
# ชาวนา	cʰaaw naa
# อายุ	ʔaa yúʔ
# 49	sìi sìp kâaw
# ปี	pii
# ตาม	taam
# หมายจับ	mǎay càp
# ศาลจังหวัด	sǎan caŋ wàt
# พิจิตร	pʰíʔ cìt
# ที่	tʰîi
# 12	sìp sɔ̌ɔŋ
# /	/
# 2553	sɔ̌ɔŋ pʰan hâa rɔ́ɔy hâa sìp sǎam
# ลงวันที่	loŋ wan tʰîi
# 15	sìp hâa
# ม.ค.	mók kà raa kʰom
# 2553	sɔ̌ɔŋ pʰan hâa rɔ́ɔy hâa sìp sǎam
# ข้อหา	kʰɔ̂ɔ hǎa
# "	"
# ร่วมกัน	rûam kan
# ฆ่า	kʰâa
# ผู้อื่น	pʰûu ʔɯ̀ɯn
# โดยเจตนา	dooy cèet tà naa
# "	"
# ได้ที่	dây tʰîi
# ริม	rim
# ถนนสาธารณะ	tʰà nǒn sǎa tʰaa rá ná
# ซอย	sɔɔy
# 9	kâaw
# ถนน	tʰà nǒn
# บาง	baaŋ
# แสน	sɛ̌ɛn
# สาย	sǎay
# 2	sɔ̌ɔŋ
# ต.	tam bon
# แสน	sɛ̌ɛn
# สุข	sùk
# อ.	ʔɔɔ
# เมือง	mɯaŋ
# จ.	cɔɔ
# ชลบุรี	cʰon bùʔ rii
# ...	...
# อ่าน	ʔàan
# ต่อ	tɔ̀ɔ
# ที่	tʰîi
# :	:

# %%
thaig2p.__get_phone_word_tltk('')
# Out:
# ( aaa )

# %% [markdown]
# # validate

# %%
data = pd.read_csv('thai2phone.csv')
# rows with phone
w = data[~data.phone.isna()]
# rows without phone
wo = data[data.phone.isna()]

# %%
# check invalid phone
for p in w.phone:
    if not thaig2p.__validate(p):
        print(p)
        break

# %%
# compound words
morph = "มี"
moprh_phone = "mI-1 "
hai = wo[wo.thai.str.startswith(morph)]
thai = set(w.thai)
for i, row in hai.iterrows():
    back = row.thai.replace(morph, '', 1)
    if back in thai:
        print(row.thai, moprh_phone + thaig2p.__get_phone_word(back), sep=',')

# %% [markdown]
# # add annotated data

# %%
# select either

#with open('kan.csv') as f:
with open('nophone.csv') as f:
    kan = dict(csv.reader(f))
    kan = {k:v for k,v in kan.items() if v != ''}

# %%
for i, row in data.iterrows():
    if row.thai in kan:
        data.iloc[i].phone = kan[row.thai]

# %%
data.to_csv('thai2phone.csv', index=False)

# %% [markdown]
# # tokenize

# %%
df = pd.read_csv('tweet.csv')
df['tokens'] = df.tweet.apply(g2p.tokenize)

# %%
df[['tokens','ID']].to_csv('twitter.csv', index=False)

# %% [markdown]
# # analyze

# %%
def entropy(counter):
    total = sum(counter.values())
    entropy = -sum(np.log2(count/total)*(count/total) for count in counter.values())
    return total, entropy

class Freq:
    def __init__(self):
        self.freq = Counter()
        self.freq_nostop = Counter()

class Domain:
    def __init__(self, domain_name):
        self.df = pd.read_csv(f'{domain_name}.csv')
        self.domain = domain_name.upper()
        self.calc_word_freq()

    def calc_word_freq(self):
        # word frequency
        self.word_freq = Counter()
        self.word_freq_nostop = Counter()
        # vowel frequency (word base)
        self.vowel_freq = Counter()
        self.vowel_freq_nostop = Counter()
        self.vowel_tone_freq = Counter()
        self.vowel_tone_freq_nostop = Counter()
        # vowel frequency (syllable base)
        self.vowel2_freq = Counter()
        self.vowel2_freq_nostop = Counter()
        self.vowel2_tone_freq = Counter()
        self.vowel2_tone_freq_nostop = Counter()
        # coda/onset frequency (word base)
        self.coda_freq = Counter()
        self.coda_freq_nostop = Counter()
        self.onset_freq = Counter()
        self.onset_freq_nostop = Counter()
        # coda/onset frequency (syllable base)
        self.coda2_freq = Counter()
        self.coda2_freq_nostop = Counter()
        self.onset2_freq = Counter()
        self.onset2_freq_nostop = Counter()
        # calculate
        for row in tqdm.tqdm(self.df.tokens): # iterate each text: list of tokens
            # only Thaiword token list
            tokens = [w for w in eval(row) if re.match(r'[ก-๙][ก-๙\.\- ]*$', w)] # only thaiword
            tokens_nostop = [w for w in tokens if w not in STOPWORDS]
            # phone list (only convertable words)
            phones = list(filter(lambda x:x!=None, [g2p.get_phone_oneword(w, return_none=True) for w in tokens]))
            phones_nostop = list(filter(lambda x:x!=None, [g2p.get_phone_oneword(w, return_none=True) for w in tokens_nostop]))
            # word frequency
            self.word_freq.update(tokens)
            self.word_freq_nostop.update(tokens_nostop)
            # vowel frequency 
            vowels = [g2p.get_vowels(p, ipa=True) for p in phones] # [(a,aa), (a,ua),(u),..]
            vowels_nostop = [g2p.get_vowels(p, ipa=True) for p in phones_nostop]
            self.vowel_freq.update(vowels) # word base
            self.vowel_freq_nostop.update(vowels_nostop) # word base
            self.vowel2_freq.update(sum(map(list, vowels), [])) # syl base
            self.vowel2_freq_nostop.update(sum(map(list, vowels_nostop), [])) # syl base
            # vowel tone frequency
            vowels_tone = [g2p.get_vowels_tone(p, ipa=True) for p in phones] # [(a,aa), (a,ua),(u),..]
            vowels_tone_nostop = [g2p.get_vowels_tone(p, ipa=True) for p in phones_nostop]
            self.vowel_tone_freq.update(vowels_tone) # word base
            self.vowel_tone_freq_nostop.update(vowels_tone_nostop) # word base
            self.vowel2_tone_freq.update(sum(map(list, vowels_tone), [])) # syl base
            self.vowel2_tone_freq_nostop.update(sum(map(list, vowels_tone_nostop), [])) # syl base
            # coda frequency 
            codas = [g2p.get_codas(p, ipa=True) for p in phones] # [(k,-), (t,p),(-),..]
            codas_nostop = [g2p.get_codas(p, ipa=True) for p in phones_nostop]
            self.coda_freq.update(codas) # word base
            self.coda_freq_nostop.update(codas_nostop) # word base
            self.coda2_freq.update(sum(map(list, codas), [])) # syl base
            self.coda2_freq_nostop.update(sum(map(list, codas_nostop), [])) # syl base
            # onset frequency 
            onsets = [g2p.get_onsets(p, ipa=True) for p in phones] # [(k,-), (t,p),(-),..]
            onsets_nostop = [g2p.get_onsets(p, ipa=True) for p in phones_nostop]
            self.onset_freq.update(onsets) # word base
            self.onset_freq_nostop.update(onsets_nostop) # word base
            self.onset2_freq.update(sum(map(list, onsets), [])) # syl base
            self.onset2_freq_nostop.update(sum(map(list, onsets_nostop), [])) # syl base

        # word entropy
        self.all_token, self.entropy = entropy(self.word_freq)
        self.all_token_nostop, self.entropy_nostop = entropy(self.word_freq_nostop)

        # vowel entropy
        self.all_vowel, self.vowel_entropy = entropy(self.vowel_freq)
        self.all_vowel_nostop, self.vowel_entropy_nostop = entropy(self.vowel_freq_nostop)
        self.all_vowel2, self.vowel2_entropy = entropy(self.vowel2_freq)
        self.all_vowel2_nostop, self.vowel2_entropy_nostop = entropy(self.vowel2_freq_nostop)

        # vowel tone entropy
        self.all_vowel_tone, self.vowel_tone_entropy = entropy(self.vowel_tone_freq)
        self.all_vowel_tone_nostop, self.vowel_tone_entropy_nostop = entropy(self.vowel_tone_freq_nostop)
        self.all_vowel2_tone, self.vowel2_tone_entropy = entropy(self.vowel2_tone_freq)
        self.all_vowel2_tone_nostop, self.vowel2_tone_entropy_nostop = entropy(self.vowel2_tone_freq_nostop)

        # coda entropy
        self.all_coda, self.coda_entropy = entropy(self.coda_freq)
        self.all_coda_nostop, self.coda_entropy_nostop = entropy(self.coda_freq_nostop)
        self.all_coda2, self.coda2_entropy = entropy(self.coda2_freq)
        self.all_coda2_nostop, self.coda2_entropy_nostop = entropy(self.coda2_freq_nostop)

        # onset entropy
        self.all_onset, self.onset_entropy = entropy(self.onset_freq)
        self.all_onset_nostop, self.onset_entropy_nostop = entropy(self.onset_freq_nostop)
        self.all_onset2, self.onset2_entropy = entropy(self.onset2_freq)
        self.all_onset2_nostop, self.onset2_entropy_nostop = entropy(self.onset2_freq_nostop)

    def show_entropy(self):
        print(f'----- {self.domain} -----')
        print(f'Entropy with stopwords: {self.entropy:.3f}')
        print(f'Entropy w/o  stopwords: {self.entropy_nostop:.3f}')
        print(f'Vowel2 Entropy with stopwords: {self.vowel2_entropy:.3f}')
        print(f'Vowel2 Entropy w/o  stopwords: {self.vowel2_entropy_nostop:.3f}')
        print(f'Vowel2-Tone Entropy with stopwords: {self.vowel2_tone_entropy:.3f}')
        print(f'Vowel2-Tone Entropy w/o  stopwords: {self.vowel2_tone_entropy_nostop:.3f}')
        print(f'Onset2 Entropy with stopwords: {self.onset2_entropy:.3f}')
        print(f'Onset2 Entropy w/o  stopwords: {self.onset2_entropy_nostop:.3f}')
        print(f'Coda2 Entropy with stopwords: {self.coda2_entropy:.3f}')
        print(f'Coda2 Entropy w/o  stopwords: {self.coda2_entropy_nostop:.3f}')    
        print(f'Vowel Entropy with stopwords: {self.vowel_entropy:.3f}')
        print(f'Vowel Entropy w/o  stopwords: {self.vowel_entropy_nostop:.3f}')
        print(f'Vowel-Tone Entropy with stopwords: {self.vowel_tone_entropy:.3f}')
        print(f'Vowel-Tone Entropy w/o  stopwords: {self.vowel_tone_entropy_nostop:.3f}')    
        print(f'Onset Entropy with stopwords: {self.onset_entropy:.3f}')
        print(f'Onset Entropy w/o  stopwords: {self.onset_entropy_nostop:.3f}')
        print(f'Coda Entropy with stopwords: {self.coda_entropy:.3f}')
        print(f'Coda Entropy w/o  stopwords: {self.coda_entropy_nostop:.3f}')
        
    def show_word_freq(self, n=20, nostop=False):
        print(f'----- {self.domain} -----')
        if not nostop:
            for x in self.word_freq.most_common(n):
                print(x[0], round(x[1]/self.all_token*1000000,3),sep='\t')
        else:
            for x in self.word_freq_nostop.most_common(n):
                print(x[0], round(x[1]/self.all_token_nostop*1000000,3),sep='\t')

    def show_coda_freq(self, n=100, nostop=False):
        if not nostop:
            print('----- syllable -----')
            for x in self.coda2_freq.most_common(n):
                print(' '.join(x[0]), round(x[1]/self.all_coda2*100, 3),sep='\t')
            print('\n----- word -----')
            for x in self.coda_freq.most_common(n):
                print(' '.join([c if c != '' else '-' for c in x[0]]), round(x[1]/self.all_coda*100, 3),sep='\t')
        else:
            print('----- syllable -----')
            for x in self.coda2_freq_nostop.most_common(n):
                print(' '.join(x[0]), round(x[1]/self.all_coda2_nostop*100, 3),sep='\t')
            print('\n----- word -----')
            for x in self.coda_freq_nostop.most_common(n):
                print(' '.join([c if c != '' else '-' for c in x[0]]), round(x[1]/self.all_coda_nostop*100, 3),sep='\t')

    def show_onset_freq(self, n=100, nostop=False):
        if not nostop:
            print('----- syllable -----')
            for x in ['s', 'tʰ', 'r', 'n', 'k', 'kʰ', 'pʰ', 'm', 't', 'l', 'tɕʰ', 'b', 'tɕ', 'w', 'ʔ', 'j', 'd', 'p', 'h', 'pr', 'ŋ', 'kr', 'kʰw', 'f', 'tr', 'kʰr', 'pʰr', 'kl', 'kʰl', 'pl', 'pʰl', 'kw', 'fr', 'br', 'tʰr', 'dr', 'fl', 'bl']:
                print(x, round(self.onset2_freq[x]/self.all_onset2*100, 3),sep='\t')
            print('\n----- word -----')
            for x in self.onset_freq.most_common(n):
                print(' '.join(x[0]), round(x[1]/self.all_onset*100, 3),sep='\t')
        else:
            print('----- syllable -----')
            for x in ['s', 'tʰ', 'r', 'n', 'k', 'kʰ', 'pʰ', 'm', 't', 'l', 'tɕʰ', 'b', 'tɕ', 'w', 'ʔ', 'j', 'd', 'p', 'h', 'pr', 'ŋ', 'kr', 'kʰw', 'f', 'tr', 'kʰr', 'pʰr', 'kl', 'kʰl', 'pl', 'pʰl', 'kw', 'fr', 'br', 'tʰr', 'dr', 'fl', 'bl']:
                print(x, round(self.onset2_freq_nostop[x]/self.all_onset2_nostop*100, 3),sep='\t')
            print('\n----- word -----')
            for x in self.onset_freq_nostop.most_common(n):
                print(' '.join(x[0]), round(x[1]/self.all_onset_nostop*100, 3),sep='\t')

    def show_vowel_freq(self, n=20, nostop=False):
        print(f'----- {self.domain} -----')
        if not nostop:
            print('\n----- syl -----')
            for vowel in ['a', 'aa', 'ɔɔ', 'ii', 'o', 'i', 'u', 'ua', 'ɛɛ', 'uu', 'ee', 'e', 'oo', 'ɯa', 'əə', 'ɯ', 'ɛ', 'ia', 'ɯɯ', 'ɔ', 'ə']:
                print(vowel, round(self.vowel2_freq[vowel]/self.all_vowel2*100, 3),sep='\t')

            print('\n----- syl tone -----')
            for vowel, count in self.vowel2_tone_freq.most_common(n):
                print(vowel, round(count/self.all_vowel2_tone*100, 3),sep='\t')

            print('\n----- word -----')
            for vowel, count in self.vowel_freq.most_common(n):
                print(' '.join(vowel), round(count/self.all_vowel*100, 3),sep='\t')

            print('\n----- word tone -----')
            for vowel, count in self.vowel_tone_freq.most_common(n):
                print(' '.join(vowel), round(count/self.all_vowel_tone*100, 3),sep='\t')

        else:
            print('\n----- syl -----')
            for vowel in ['a', 'aa', 'ɔɔ', 'ii', 'o', 'i', 'u', 'ua', 'ɛɛ', 'uu', 'ee', 'e', 'oo', 'ɯa', 'əə', 'ɯ', 'ɛ', 'ia', 'ɯɯ', 'ɔ', 'ə']:
                print(vowel, round(self.vowel2_freq_nostop[vowel]/self.all_vowel2_nostop*100, 3),sep='\t')

            print('\n----- syl tone -----')
            for vowel, count in self.vowel2_tone_freq_nostop.most_common(n):
                print(vowel, round(count/self.all_vowel2_tone_nostop*100, 3),sep='\t')

            print('\n----- word -----')
            for vowel, count in self.vowel_freq_nostop.most_common(n):
                print(' '.join(vowel), round(count/self.all_vowel_nostop*100, 3),sep='\t')

            print('\n----- word tone -----')
            for vowel, count in self.vowel_tone_freq_nostop.most_common(n):
                print(' '.join(vowel), round(count/self.all_vowel_tone_nostop*100, 3),sep='\t')

# %%
data = Domain('twitter')
#pantip = Domain('pantip')
#thairath = Domain('thairath')
# Out:
# 100%|██████████| 485000/485000 [03:41<00:00, 2193.82it/s]

# %%
data.show_entropy()
# Out:
# ----- TWITTER -----
# Entropy with stopwords: 10.670
# Entropy w/o  stopwords: 11.638
# Vowel2 Entropy with stopwords: 3.520
# Vowel2 Entropy w/o  stopwords: 3.692
# Vowel2-Tone Entropy with stopwords: 5.535
# Vowel2-Tone Entropy w/o  stopwords: 5.713
# Onset2 Entropy with stopwords: 4.459
# Onset2 Entropy w/o  stopwords: 4.504
# Coda2 Entropy with stopwords: 3.015
# Coda2 Entropy w/o  stopwords: 2.989
# Vowel Entropy with stopwords: 5.052
# Vowel Entropy w/o  stopwords: 5.888
# Vowel-Tone Entropy with stopwords: 7.153
# Vowel-Tone Entropy w/o  stopwords: 8.021
# Onset Entropy with stopwords: 6.057
# Onset Entropy w/o  stopwords: 6.802
# Coda Entropy with stopwords: 4.466
# Coda Entropy w/o  stopwords: 5.058

# %%
data.show_coda_freq(100, nostop=True)
# Out:
# ----- syllable -----
# 	32.294
# n	14.908
# ŋ	9.828
# j	8.189
# k	7.003
# t	6.865
# m	6.411
# ʔ	6.169
# p	4.464
# w	3.733
# f	0.067
# d	0.047
# l	0.013
# s	0.01
#
# ----- word -----
# -	21.06
# n	10.811
# ŋ	7.333
# j	5.326
# ʔ	5.139
# k	5.012
# m	4.502
# t	3.984
# p	3.324
# w	3.071
# - -	2.867
# - k	1.448
# n -	1.227
# - t	1.16
# - ŋ	0.97
# - j	0.92
# - n	0.853
# n n	0.656
# ŋ n	0.618
# - ʔ	0.588
# p -	0.569
# ŋ -	0.558
# n j	0.542
# t ŋ	0.466
# ŋ j	0.431
# k -	0.395
# m n	0.394
# p n	0.388
# w -	0.373
# - m	0.358
# j n	0.33
# ŋ ŋ	0.303
# m -	0.296
# k j	0.295
# - w	0.294
# j -	0.28
# t -	0.271
# j ŋ	0.268
# m j	0.267
# t j	0.254
# n w	0.252
# n ŋ	0.25
# j j	0.235
# k n	0.222
# - p	0.217
# ʔ t	0.21
# t n	0.206
# - - -	0.192
# k ŋ	0.182
# m ŋ	0.176
# m t	0.173
# ʔ n	0.173
# m k	0.163
# ʔ ʔ	0.16
# k w	0.158
# ʔ -	0.157
# n k	0.152
# p m	0.143
# w j	0.143
# - t -	0.142
# n t	0.133
# m m	0.132
# t t	0.131
# k k	0.131
# m p	0.13
# n p	0.127
# ŋ m	0.125
# - - n	0.124
# t m	0.116
# - - t	0.113
# ŋ k	0.112
# p p	0.109
# ʔ j	0.106
# n m	0.1
# - m k	0.096
# p j	0.094
# j m	0.09
# ŋ t	0.086
# ŋ w	0.086
# - t t	0.083
# t - -	0.082
# m - k	0.081
# w ŋ	0.077
# ʔ ŋ	0.076
# n ʔ	0.076
# f	0.076
# n - -	0.072
# ʔ p	0.07
# j w	0.069
# k - ʔ	0.068
# - ʔ n	0.067
# n - t	0.066
# ŋ p	0.065
# - n -	0.063
# p t	0.063
# j t	0.061
# - - j	0.061
# j p	0.059
# t k	0.058
# w w	0.056

# %%
importlib.reload(g2p)
# Out:
# <module 'g2p' from '/Users/Nozomi/Library/Mobile Documents/com~apple~CloudDocs/g2p/g2p.py'>

# %%
data.show_word_freq(1000, nostop=True)
# Out:
# ----- TWITTER -----
# พี่	11585.171
# คน	10273.041
# กก	7078.544
# ดี	6898.11
# ทำ	6418.903
# งง	6096.722
# อ่ะ	5843.79
# ออ	5541.115
# ดู	5531.037
# น้อง	5486.498
# ชอบ	5442.608
# ผม	5143.835
# นอน	5063.859
# อะ	4922.113
# รัก	4522.232
# รู้	4212.73
# แม่	3910.381
# น่ารัก	3896.727
# เค้า	3778.388
# ง	3623.962
# กิน	3556.665
# นะคะ	3343.72
# อย่า	3263.419
# หรอ	3089.162
# น	3068.03
# เรื่อง	2884.345
# เหมือน	2847.608
# ค	2799.492
# ตัวเอง	2659.696
# เล่น	2658.396
# เพลง	2650.593
# สิ	2630.437
# เจอ	2549.81
# รอ	2548.51
# ตื่น	2548.185
# หน้า	2543.958
# ตอน	2542.333
# คิดถึง	2536.806
# อ	2385.306
# เพื่อน	2310.857
# ตอนนี้	2297.203
# แบบนี้	2291.351
# ล่ะ	2263.717
# งาน	2213.325
# ไหม	2169.111
# เดี๋ยว	2079.706
# อี	2063.776
# วะ	2059.225
# อ่าน	2058.574
# ม	2048.821
# คุย	2035.492
# แฟน	2032.241
# ย	2024.438
# ตัว	2012.734
# เวลา	2006.232
# ไทย	1980.874
# หา	1951.614
# บ้าน	1942.186
# รู้สึก	1942.186
# ล	1926.581
# โดน	1924.305
# กุ	1921.054
# ใจ	1918.454
# รี	1918.128
# ปี	1898.947
# ค่า	1891.145
# หนู	1887.243
# รูป	1873.589
# สวย	1857.659
# หล่อ	1850.181
# ใส่	1824.823
# เด็ก	1798.814
# บอ	1795.563
# ขนาด	1790.036
# ก	1783.209
# ขอบคุณ	1766.629
# ซื้อ	1760.127
# เรียน	1669.097
# ตาย	1618.705
# ส	1591.071
# ว	1582.293
# ยย	1541.655
# หาย	1499.391
# ฮือ	1492.889
# กะ	1480.86
# นั่ง	1479.235
# น้า	1464.28
# ถาม	1464.28
# ลืม	1437.946
# ลูก	1417.464
# แบ	1379.102
# ต	1369.349
# ติด	1309.204
# เหี้ย	1299.776
# หรอก	1295.549
# เท	1284.821
# ตอบ	1278.319
# เหมือนกัน	1269.541
# เหรอ	1257.837
# ชีวิต	1255.561
# สู้	1253.936
# ไอ	1233.129
# อิ	1221.75
# ยอง	1211.672
# เช้า	1211.022
# ยิ้ม	1205.495
# สอง	1203.544
# ทวิ	1201.919
# กลัว	1195.742
# า	1175.585
# นึง	1172.984
# ไม่ต้อง	1171.684
# ฟัง	1165.182
# ์	1163.231
# ดิ	1162.906
# ชื่อ	1151.852
# พ่อ	1146.976
# รอบ	1142.424
# าา	1142.099
# จบ	1140.799
# ว่ะ	1135.922
# ยู	1134.622
# ทัก	1133.972
# ริ	1128.445
# เมน	1123.893
# ป่ะ	1116.741
# ฮ	1101.136
# ๆๆ	1101.136
# ยยย	1096.584
# ป	1089.757
# บ	1087.156
# ง่วง	1082.93
# อา	1066.674
# จี	1063.749
# กลับมา	1053.995
# ขาย	1053.345
# เดิน	1049.769
# เม	1049.769
# ตา	1025.061
# เหนื่อย	1022.46
# งี้	1015.633
# อ่า	1012.707
# ท	1007.18
# หัว	1004.579
# ดีกว่า	1003.929
# คับ	997.102
# โหวต	991.575
# โอ้ย	978.245
# สอบ	975.645
# ไหว	972.719
# แง	966.217
# สวัสดี	961.665
# แอ	960.04
# ตี	954.838
# คนเดียว	954.838
# คนอื่น	951.912
# งั้น	950.286
# เซ	947.36
# มอ	945.735
# ทำงาน	942.809
# บาท	939.883
# โคตร	938.257
# มะ	937.282
# สี	935.657
# น.	934.356
# ลอง	933.056
# เดือน	931.755
# เบื่อ	925.578
# ด	922.652
# เด	922.327
# สนใจ	922.327
# ขอให้	917.776
# ปะ	915.5
# หลับ	910.298
# ขำ	905.747
# ชั้น	905.422
# กอด	885.265
# อยากได้	883.64
# เ	875.837
# วันที่	873.886
# ด่า	867.709
# พรุ่งนี้	867.059
# โลก	864.133
# โอเค	863.158
# เจ	862.833
# เงิน	857.631
# นา	856.005
# แล้วก็	848.853
# ร้องไห้	840.075
# โอ	834.874
# ค้าบ	833.573
# เออ	832.923
# คู่	828.371
# ผลิต	824.145
# เลือก	819.919
# เก่ง	819.594
# เจ็บ	817.643
# ป่าว	816.017
# กด	814.717
# สาย	814.067
# ร้อง	811.141
# ราคา	810.491
# ยอน	809.84
# เขิน	806.264
# บ้า	798.462
# เสียง	794.235
# ฮา	793.585
# ห้อง	790.009
# ออกมา	787.733
# คอน	782.856
# ฝันดี	782.206
# อีกแล้ว	777.98
# กี่	774.079
# เอ	771.803
# มีความสุข	768.877
# สัก	768.877
# นิ่ง	767.902
# เต	764.976
# เกลียด	764.325
# น้ำ	762.375
# หิว	757.823
# ชั่น	757.823
# หยุด	756.523
# ๆๆๆ	754.247
# ฮะ	750.996
# ร้าน	750.996
# รีบ	748.395
# โชค	745.794
# ข่าว	736.041
# บัตร	735.391
# ทีม	734.416
# นิ	729.864
# จ	729.539
# เป๊ก	719.786
# วว	718.16
# รร	714.584
# ว่าง	712.959
# มือ	712.633
# ก้	711.333
# โมง	709.382
# เนอะ	707.432
# ฟอ	706.782
# แรง	701.905
# เจ้า	701.58
# เลิก	700.279
# รถ	696.053
# ปาก	695.403
# ไลน์	684.024
# ร้อน	682.399
# เค	676.547
# สาม	674.921
# เหงา	670.37
# ภาพ	669.719
# ฟรี	667.769
# สำหรับ	667.444
# วง	665.818
# ยยยย	663.542
# หัวใจ	662.892
# ตลก	658.666
# ป้า	657.04
# สัส	657.04
# รู้จัก	654.114
# าาา	652.489
# สนุก	648.587
# กา	646.962
# แน่	644.686
# อิน	643.061
# ชุด	639.159
# เสื้อ	635.583
# คลิป	634.933
# ฝัน	633.307
# จิน	632.982
# อ้วน	626.805
# แอบ	625.83
# แคป	624.855
# สั่ง	624.53
# ขอโทษ	622.579
# ปล่อย	622.579
# แทน	620.628
# ไอ้	620.303
# ม.	616.402
# ฝาก	613.801
# ที่จะ	611.2
# ตลาดนัด	609.9
# ยา	607.299
# อิอิ	605.348
# หนัก	603.398
# ดีใจ	601.122
# ผัว	600.147
# ถ่าย	599.496
# อันนี้	599.171
# สุดท้าย	598.521
# คอ	598.521
# หนัง	596.896
# หมา	594.295
# เห	592.669
# แจ	590.719
# พ	586.817
# นน	585.842
# สาว	585.192
# ไปหา	580.965
# นึก	579.34
# เจอกัน	579.34
# ววว	572.838
# ร้า	571.212
# ก้อ	568.936
# ดึก	567.961
# แน่ๆ	566.01
# เต็ม	565.035
# เฮีย	564.385
# อร	562.759
# จิ	562.109
# บี	559.833
# ชิ	559.833
# ชา	556.582
# ร	556.582
# ต่อไป	555.607
# ความรัก	553.981
# ดีมาก	553.006
# โค	552.356
# แมว	552.356
# ล่า	550.73
# ติ่ง	550.08
# ตก	549.105
# ฮ่า	546.829
# หมอ	544.553
# เย	541.302
# โพสต์	540.327
# เกาหลี	540.327
# ซัก	539.352
# เมีย	539.352
# โว้ย	537.726
# ร์	534.8
# มั้ง	532.199
# ก.	531.224
# เดิม	531.224
# แย่	530.899
# ไว	527.648
# ความรู้สึก	525.047
# อร่อย	523.421
# ขา	522.771
# ไปดู	520.821
# ยุ	518.87
# ห	513.018
# ดำ	513.018
# ปกติ	512.368
# ขี้	511.067
# วิ่ง	510.417
# ทิ้ง	509.117
# เย็น	507.166
# ไฟ	506.841
# ซี	506.191
# กรี๊ด	504.89
# กล้า	500.014
# ชาน	498.713
# เต้น	495.787
# ผู้ชาย	494.487
# เก	493.837
# แล้	492.536
# แดก	491.236
# จา	490.586
# จอง	489.936
# โทร	489.936
# ลิ	487.985
# เสียใจ	486.359
# ยอ	486.359
# ใบ	486.034
# รี่	486.034
# สสส	482.458
# เครียด	478.882
# วิ	478.232
# เข้ามา	477.581
# หนาว	476.281
# พระ	475.956
# แจก	472.705
# ยืน	469.129
# เข้าไป	469.129
# เหอะ	469.129
# เกม	468.478
# ประเทศ	468.153
# ใส	466.853
# เเล้ว	465.227
# ผี	463.927
# แต่ง	461.651
# โฮ	459.701
# ลุง	459.701
# ขาว	459.701
# นัด	456.124
# เบอร์	455.799
# โม	452.548
# เสมอ	452.223
# เว้ย	451.248
# ฮุน	450.598
# คา	447.672
# สรุป	446.696
# ชม	445.721
# ล้าน	445.721
# ตัง	445.071
# ปวด	444.746
# วจะ	444.746
# สงสาร	444.095
# ะ	443.445
# นก	442.47
# สงสัย	442.145
# อ่อ	441.82
# กลับบ้าน	441.17
# สา	440.519
# อยู่แล้ว	440.194
# รูปภาพ	437.918
# อ.	437.268
# ห้าม	436.943
# กินข้าว	433.367
# ซิ	432.392
# ตะ	431.091
# ท่าน	428.49
# บิน	427.19
# จุ	426.215
# จุด	426.215
# ลด	425.239
# ตัด	423.614
# เปน	422.638
# ที่รัก	421.663
# สี่	421.013
# แพ้	419.713
# น้ำตา	419.387
# ตั้งใจ	417.762
# คืน	416.787
# หมี	416.136
# หมู	414.836
# ให้ได้	414.186
# แป	414.186
# ครึ่ง	413.21
# ย์	411.26
# เหมือนเดิม	410.935
# ฟ	410.61
# ลา	409.959
# รายการ	409.309
# บัง	408.009
# หวัง	408.009
# สส	408.009
# แปล	405.733
# อัพ	405.733
# ฟ้า	405.083
# เก่า	402.482
# เศร้า	401.181
# อห	399.556
# โสด	398.255
# เร	396.63
# อาบน้ำ	396.305
# แก้ม	395.655
# ฟิค	394.029
# เลี้ยง	393.704
# ๆๆๆๆ	392.404
# มาจาก	392.404
# แน่นอน	391.753
# เอ้ย	391.753
# แตก	389.478
# อากาศ	389.152
# ช่อง	387.527
# นอ	386.877
# พัก	385.576
# เกินไป	384.926
# อู	383.951
# ขี้เกียจ	383.626
# ฝน	381.35
# อ้าว	379.724
# นนน	378.099
# ยยยยย	377.449
# บ่น	376.473
# ทำได้	376.148
# นอนไม่หลับ	375.498
# คอม	375.173
# นาที	375.173
# ต้องการ	374.848
# สอน	374.848
# ทน	374.523
# รีวิว	374.198
# โอ๊ย	373.547
# ซา	373.222
# บ.	372.572
# พัง	369.971
# ผู้หญิง	369.646
# วัด	369.321
# แถว	368.996
# โซ	368.671
# ห้า	368.346
# กี้	368.346
# คุ	368.021
# แถม	366.07
# วน	364.119
# เรย	363.794
# เห้อ	363.794
# าาาา	362.819
# เฟส	362.169
# วอน	362.169
# หนี	361.844
# ดราม่า	360.868
# แท็ก	360.218
# นม	359.568
# รา	359.243
# ดูแล	358.592
# อาทิตย์	357.942
# บบ	356.317
# บางคน	355.341
# วววว	355.341
# สร้าง	355.341
# ท่า	354.691
# ชวน	354.041
# ช	353.716
# แสน	353.391
# ซอง	353.391
# หัวเราะ	353.066
# โง่	352.09
# นุช	351.765
# แดง	350.465
# หู	349.815
# เบา	349.49
# อารมณ์	348.839
# แห	347.864
# พน	346.564
# วี	346.564
# ไห	346.238
# ตอนแรก	345.588
# ชาย	344.938
# อก	344.288
# ออกจาก	341.687
# บอล	341.037
# กำลังใจ	340.712
# อุ	340.061
# ฿	340.061
# ถ่ายรูป	339.736
# มาร์ค	339.736
# ครับผม	339.411
# โห	339.086
# ครู	338.111
# ฟิน	337.461
# เมือง	336.485
# ชิบหาย	335.51
# ทุ่ม	335.185
# โด	332.909
# คืนนี้	331.934
# ห่า	331.934
# จุน	331.609
# ข้าว	331.284
# เย้	330.308
# แมน	329.983
# หวาน	329.658
# เที่ยว	329.333
# ซู	329.333
# ตอนนั้น	327.707
# ญี่ปุ่น	327.707
# ปั่น	323.806
# เตรียม	322.506
# สิบ	322.506
# เด้อ	321.855
# อายุ	321.53
# พิมพ์	321.205
# แร้ว	321.205
# วิดีโอ	320.23
# ทา	320.23
# แกล้ง	319.255
# เสือก	319.255
# เชียร์	317.954
# พัน	317.304
# ตบ	317.304
# ฟังเพลง	316.654
# แปลก	315.353
# เม้น	315.353
# คนดี	314.703
# หอ	313.728
# ไหล	313.403
# จีน	313.078
# หลง	311.127
# ดา	310.802
# คค	310.477
# ประกาศ	309.501
# ลบ	308.851
# เอม	308.526
# วันเกิด	307.551
# มาหา	307.551
# อีกที	307.551
# ฝนตก	306.25
# แอด	305.275
# ชิน	305.275
# ชัด	304.625
# จ่าย	304.625
# ได้ยิน	303.975
# คบ	303.975
# อรุณสวัสดิ์	302.999
# ยังมี	302.999
# ง่ะ	302.349
# แท	301.699
# พิ	301.699
# หลุด	300.724
# ยืม	298.123
# การ์ด	297.472
# ะะ	296.497
# เครื่อง	296.497
# ขอบ	295.197
# ร้าย	294.547
# เปล่า	294.547
# ปวดหัว	294.221
# จอ	293.246
# กรอบ	292.271
# แก้	292.271
# หนังสือ	291.946
# คอย	291.621
# โอน	291.295
# กล้อง	289.995
# ดาว	289.67
# บิ	289.67
# น่ากลัว	283.168
# จีบ	282.843
# แนว	282.192
# ตอนที่	281.867
# ร้องเพลง	281.867
# รึเปล่า	280.892
# ทำตัว	280.567
# ชิป	279.917
# เจ้	278.941
# โรงเรียน	278.291
# เมา	277.966
# สักที	277.966
# จิง	276.991
# ฆ่า	276.991
# ยินดี	276.666
# เน็ต	275.69
# ปา	275.04
# หอม	275.04
# ทอง	275.04
# ติดตาม	274.715
# เฮ	274.065
# กระเป๋า	274.065
# ข้อมูล	274.065
# ดิส	273.74
# เท่	271.789
# แทบ	271.464
# แต่เช้า	270.814
# ช่าง	270.814
# ชาติ	270.814
# โชว์	270.814
# พลาด	269.838
# รุ	269.838
# ยอด	269.188
# เปิดตัว	269.188
# หญิง	268.538
# ผ้า	267.888
# ทาน	267.238
# หนุ่ม	266.912
# อาหาร	266.587
# ลุ้น	266.587
# หน้าตา	266.262
# รำคาญ	265.937
# เฮ้อ	264.962
# นึกถึง	264.637
# กวน	264.312
# เล่า	263.986
# ตีน	263.986
# แพง	263.336
# ร้อย	263.336
# แนะนำ	263.011
# ฮิ	262.686
# ยัย	262.686
# อี้	262.361
# รน	262.361
# พี	261.061
# ลาย	260.735
# เลา	260.735
# คะแนน	260.41
# ควย	260.085
# บาย	259.76
# โปร	259.435
# บ่าย	259.11
# ครอบครัว	258.785
# โน	258.46
# ส่อง	258.46
# เดินทาง	257.159
# แลก	256.834
# กลายเป็น	256.184
# ความสุข	255.209
# ความจริง	254.558
# รวย	254.233
# ไม	254.233
# ดัน	253.583
# งอน	251.632
# ไปเที่ยว	251.307
# ตกใจ	251.307
# โหด	251.307
# วา	250.982
# คิว	250.982
# เกา	250.657
# ตื่นเต้น	249.682
# ทำร้าย	249.357
# เอส	248.706
# ชนะ	248.706
# ยุ่ง	248.381
# เสาร์	248.381
# ออนไลน์	248.381
# โก	248.056
# โย	248.056
# แฟนคลับ	247.731
# เล่ม	247.406
# วาด	246.431
# โบ	246.431
# จู	246.431
# ลี่	246.106
# เอ็ม	244.805
# ระ	244.48
# ชม.	244.155
# ดีแล้ว	244.155
# เงียบ	244.155
# อม	243.505
# ชั่วโมง	242.529
# ไล่	242.204
# ค่าย	241.879
# แพ	241.229
# สน	240.579
# คนละ	239.929
# เเต่	239.929
# อยากรู้	239.604
# สบายใจ	239.278
# เสียดาย	239.278
# ยิง	238.953
# เพ	238.303
# วิน	238.303
# แจ้ง	237.653
# เลอ	237.328
# แยก	237.328
# สายตา	237.328
# แฮ	237.003
# โอย	236.678
# ทั้งวัน	236.352
# รัช	236.027
# ม้า	236.027
# พวกเรา	236.027
# แขน	236.027
# ตรงนี้	234.402
# โกรธ	234.077
# ทู	233.101
# เรือ	233.101
# ติ	232.451
# รัว	232.126
# ดดด	232.126
# นนนน	231.801
# ดด	231.801
# กัด	231.151
# โท	230.826
# เอ็นดู	230.826
# มั่ง	230.501
# สะ	229.525
# อ่านหนังสือ	229.2
# ป้ะ	229.2
# ละคร	228.875
# รุ่น	228.875
# ดึง	227.575
# รู้เรื่อง	227.249
# ตรงไหน	227.249
# มี่	227.249
# สมอง	226.599
# เวอร์	226.274
# ที่มา	226.274
# โล	225.949
# ใจเย็น	225.299
# วิชา	224.974
# ยยยยยย	224.974
# เดี๋ยวนี้	224.974
# อ่าว	224.649
# กุก	224.649
# มม	224.323
# อาย	224.323
# จันทร์	224.323
# นุ	223.998
# สัด	223.673
# มาย	223.673
# ที่อยู่	223.348
# อยู่ดี	222.048
# รู	222.048
# บ่	221.723
# ระวัง	221.723
# นิสัย	221.072
# สุดยอด	221.072
# แด	220.747
# อัลบั้ม	220.422
# ครีม	220.422
# แคร์	220.422
# สดใส	219.772
# เป็นห่วง	219.772
# ล้า	218.797
# ขนม	218.472
# ใจดี	218.472
# บั้ม	218.472
# เอ่ย	218.146
# ลู่	218.146
# โทรศัพท์	217.821
# ผิว	217.821
# บท	217.496
# ไก่	217.496
# จ.	216.846
# เนื้อ	216.846
# เลข	215.221
# ที่นี่	214.895
# โอ๋	214.57
# ๆๆๆๆๆ	214.57
# รอด	214.57
# อาจารย์	213.92
# แก้ว	213.595
# เด็ด	212.945
# เรียบร้อย	212.62
# เจน	212.62
# ภาษา	211.644
# วิธี	211.644
# สินค้า	211.644
# เนาะ	211.319
# นิยาย	211.319
# ววววว	211.319
# จำได้	210.994
# ลุก	210.994
# อืม	210.669
# โอ้	210.669
# เป็นไร	210.669
# นิ้ว	210.669
# นิว	210.344
# ปลา	210.344
# แน่น	210.344
# อิจฉา	210.019
# คนเรา	210.019
# นู	209.369
# หวง	209.369
# มุก	209.369
# สมัคร	209.043
# ยัน	209.043
# ซ้อม	208.393
# พิเศษ	208.393
# ด้อม	208.393
# หมายถึง	208.068
# สังคม	207.743
# ฉาก	207.418
# เอาไว้	207.418
# ต้น	207.418
# อยู่เลย	207.093
# ค้า	207.093
# เปิดใจ	207.093
# ป๊า	206.768
# ตลาด	206.118
# มาถึง	205.142
# กลาง	205.142
# มือถือ	205.142
# ห่วง	205.142
# สุขภาพ	204.817
# ผอม	204.492
# คนใน	204.492
# โปรด	203.517
# หลอก	203.192
# รอยยิ้ม	203.192
# เตือน	202.866
# ฮื่อ	202.541
# สด	202.541
# กล่อง	202.216
# ซ	201.891
# ข้าม	201.566
# ซัง	201.566
# บุญ	201.241
# เปง	201.241
# แปะ	200.916
# ร่าง	200.916
# ควาย	200.916
# ระดับ	200.266
# เกาะ	199.941
# มโน	199.941
# หวีด	199.615
# โพส	199.615
# บา	198.64
# ทล	198.64
# คัม	197.99
# ดับ	197.99
# พื้นที่	197.99
# สิว	197.99
# ความคิด	197.99
# เป็นไง	197.34
# อ๋อ	197.34
# ปัญหา	197.34
# พูดถึง	197.34
# นัง	197.34
# รี้	197.015
# นท	197.015
# ศุกร์	197.015
# กิ	196.689
# ออน	196.689
# ไค	196.689
# กาก	196.364
# ครั้งแรก	196.039
# เตียง	196.039
# สัญญา	196.039
# ป่วย	195.714
# ดีขึ้น	195.714
# ป.	195.714
# จิงๆ	195.064
# ช่าย	194.739
# มุม	194.739
# ข้อ	194.414
# ลูกค้า	194.089
# ดุ	194.089
# พักผ่อน	193.763
# อด	193.763
# หงุดหงิด	193.438
# ซึง	193.438
# แอร์	193.438
# สม	192.788
# หก	192.463
# งับ	192.463
# นั้นแหละ	192.138
# ตอนเช้า	191.813
# รางวัล	191.813
# สอบถาม	191.813
# สนิท	191.488
# ไลฟ์	191.163
# ทวีต	191.163
# เป็นเพื่อน	190.838
# จ้าน	190.838
# วาย	190.512
# ทะเล	190.512
# นี้แหละ	190.187
# เวที	190.187
# ปีใหม่	189.862
# พลัง	189.862
# เรียล	189.537
# ว้อย	188.562
# เป้	188.562
# อีกครั้ง	188.562
# หี	188.562
# เลือด	187.912
# แหม	187.912
# ซี่	186.936
# โหลด	186.611
# แข่ง	186.286
# มนุษย์	186.286
# ป๋า	185.961
# ดื้อ	185.636
# เนี้ย	185.311
# ซอ	184.335
# สามี	184.01
# เฮ้ย	184.01
# โทษ	184.01
# กระ	184.01
# โชคดี	183.685
# ร่างกาย	183.36
# คณะ	183.035
# พิม	182.71
# ปลุก	182.385
# คำพูด	182.385
# แค	182.385
# คัน	182.06
# ท้อง	182.06
# กราบ	181.409
# เชียงใหม่	181.409
# เย็ด	181.409
# ตังค์	181.084
# เด้	180.759
# เจ๊	180.434
# ย้อน	180.434
# ปวดท้อง	179.459
# เช้านี้	179.134
# แชร์	178.809
# โร	178.809
# วิว	178.483
# คู	177.508
# ล้อ	177.508
# คนสวย	177.183
# ชู	177.183
# วาง	177.183
# แฝด	176.858
# ร่า	176.533
# ฮี	176.533
# อง	176.208
# ก้า	176.208
# ลี	176.208
# รส	176.208
# อ่อย	176.208
# หลัก	176.208
# หนา	176.208
# คร้าบ	175.883
# อ้ะ	175.883
# ชน	175.883
# ดอก	175.558
# อิ่ม	175.558
# ส์	175.232
# ใจร้าย	174.907
# มมม	174.582
# ม่าย	173.932
# เกรด	173.932
# ขายของ	173.607
# ประเด็น	173.282
# ถนน	172.957
# ชิ้น	172.957
# คนไทย	172.632
# สั่น	172.306
# ชี้	171.981
# คุง	171.981
# พ่อแม่	171.981
# ปลอดภัย	171.656

# %%
data.vowel_freq.most_common(50)
# Out:
# [(('a',), 438733),
#  (('aa',), 429229),
#  (('ii',), 198109),
#  (('ɔɔ',), 176683),
#  (('o',), 94940),
#  (('a', 'a'), 87712),
#  (('a', 'aa'), 84567),
#  (('ɛ',), 80055),
#  (('ɛɛ',), 68970),
#  (('ɯa',), 67859),
#  (('aa', 'aa'), 63748),
#  (('e',), 60513),
#  (('uu',), 56047),
#  (('ua',), 55586),
#  (('ɯ',), 50178),
#  (('oo',), 47923),
#  (('i',), 43390),
#  (('a', 'ii'), 42045),
#  (('u',), 41329),
#  (('əə',), 32869),
#  (('ɯɯ',), 32426),
#  (('ee',), 29128),
#  (('a', 'o'), 28504),
#  (('aa', 'a'), 27112),
#  (('ɔ',), 21430),
#  (('ɔɔ', 'a'), 20653),
#  (('ia',), 19749),
#  (('a', 'a', 'aa'), 19515),
#  (('ɔɔ', 'aa'), 18741),
#  (('a', 'ua'), 17870),
#  (('ɔɔ', 'ɔɔ'), 17735),
#  (('a', 'aa', 'o'), 15006),
#  (('a', 'ɔɔ'), 14384),
#  (('a', 'u'), 14256),
#  (('a', 'ee'), 13741),
#  (('o', 'aa'), 12198),
#  (('a', 'ɛɛ'), 11927),
#  (('a', 'aa', 'ii'), 11199),
#  (('a', 'i'), 11126),
#  (('a', 'əə'), 10909),
#  (('ii', 'a'), 10468),
#  (('ɔɔ', 'ɔɔ', 'ɔɔ'), 10419),
#  (('ua', 'a'), 10380),
#  (('ee', 'aa'), 9884),
#  (('a', 'a', 'ii'), 9622),
#  (('aa', 'u'), 9479),
#  (('ɯɯ', 'ii'), 8485),
#  (('a', 'a', 'a'), 8318),
#  (('uu', 'aa'), 8147),
#  (('aa', 'ii'), 7961)]

# %%
text = "สาว|เชียร์|เบียร์|พา|ลูก~สาว|วัย<tr/>saaw4|chiia0|biia0|phaa0|luuk2~saaw4|waj0|<s/>12<tr/>12|<s/>ขวบ|โร่|แจ้ง|ตำ~รวจ|บาง|บัว|ทอง<tr/>khuuap1|roo2|cxxN2|tam0~ruuat1|baaN0|buua0|thOON0|<s/>อ้าง|ถูก|ลูก~ชาย|เจ้า~ของ|ห้อง~เช่า|ลวง|ข่ม~ขืน|ด.~ญ.<tr/>?aaN2|thuuk1|luuk2~chaaj0|caaw2~khOON4|hOON2~chaw2|luuaN0|khom1~khUUn4|dOO0~jOO0|<s/>2<tr/>2|<s/>ครั้ง<tr/>khraN3|<s/>เผย|อุ~บาย|แสบ|หลอก|ให้|แม่|ไป|เอา|เงิน|ค่า|จำ~นำ|มือ~ถือ<tr/>ph@@j4|?u1~baaj0|sxxp1|lOOk1|haj2|mxx2|paj0|?aw0|N@n0|khaa2|cam0~nam0|mUU0~thUU4|<s/>แต่|พอ|ไม่|ว่าง|ก็|ใช้|ลูก|ไป|รับ|แทน<tr/>txx1|phOO0|maj2|waaN2|kOO2|chaj3|luuk2|paj0|rap3|thxxn0|<s/>ปรา~กฏ|ฝ่าย|ด.~ญ.|ผวา|ร้อง~ไห้<tr/>praa0~kot1|faaj1|dOO0~jOO0|pha1'waa4|rOON3~haaj2|<s/>เหตุ|เพราะ|เคย|ถูก|หลอก|มา|แล้ว<tr/>heet1|phrO3|kh@@j0|thuuk1|lOOk1|maa0|lxxw3|...<tr/>...|<s/>อ่าน|ต่อ|ที่<tr/>?aan1|tOO1|thii2|<s/>:<tr/>:|<s/>https://www.dailynews.co.th/crime/809509<tr/>https://www.dailynews.co.th/crime/809509|<s/>"

# %%
sentences = re.findall(r'<tr/>(.+?)\|<s/>', text)
sentences
# Out:
# ['saaw4|chiia0|biia0|phaa0|luuk2~saaw4|waj0',
#  '12',
#  'khuuap1|roo2|cxxN2|tam0~ruuat1|baaN0|buua0|thOON0',
#  '?aaN2|thuuk1|luuk2~chaaj0|caaw2~khOON4|hOON2~chaw2|luuaN0|khom1~khUUn4|dOO0~jOO0',
#  '2',
#  'khraN3',
#  'ph@@j4|?u1~baaj0|sxxp1|lOOk1|haj2|mxx2|paj0|?aw0|N@n0|khaa2|cam0~nam0|mUU0~thUU4',
#  'txx1|phOO0|maj2|waaN2|kOO2|chaj3|luuk2|paj0|rap3|thxxn0',
#  "praa0~kot1|faaj1|dOO0~jOO0|pha1'waa4|rOON3~haaj2",
#  'heet1|phrO3|kh@@j0|thuuk1|lOOk1|maa0|lxxw3|...<tr/>...',
#  '?aan1|tOO1|thii2',
#  ':',
#  'https://www.dailynews.co.th/crime/809509']

# %%
syl = 'phaan0'
syl = re.sub(r'aa(?=\d)', 'A-', syl)
syl = re.sub(r'aa', 'A', syl)
syl
# Out:
# 'phAn0'
